# %%
#Importing librairies

#Data Transformation
import pandas as pd
import numpy as np

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Opening the data

# %%
#Generate a DataFrame
df = pd.read_pickle('airline_carrier_performance_dataset')

#Show the 5 first lines of the dataset
df.head(5)
# Out:
#      Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 0  1998.0      1.0    1.0         2.0        5.0 1998-01-02                NW
# 1  2009.0      2.0    5.0        28.0        4.0 2009-05-28                FL
# 2  2013.0      2.0    6.0        29.0        6.0 2013-06-29                MQ
# 3  2010.0      3.0    8.0        31.0        2.0 2010-08-31                DL
# 4  2006.0      1.0    1.0        15.0        7.0 2006-01-15                US
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                   19386.0                          NW      N297US  ...
# 1                   20437.0                          FL      N946AT  ...
# 2                   20398.0                          MQ      N665MQ  ...
# 3                   19790.0                          DL      N6705Y  ...
# 4                   20355.0                          US      N504AU  ...
#
#    Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID Div5AirportSeqID  \
# 0            NaN          NaN          NaN            NaN              NaN
# 1            NaN          NaN          NaN            NaN              NaN
# 2            NaN          NaN          NaN            NaN              NaN
# 3            NaN          NaN          NaN            NaN              NaN
# 4            NaN          NaN          NaN            NaN              NaN
#
#   Div5WheelsOn Div5TotalGTime  Div5LongestGTime Div5WheelsOff  Div5TailNum
# 0          NaN            NaN               NaN           NaN          NaN
# 1          NaN            NaN               NaN           NaN          NaN
# 2          NaN            NaN               NaN           NaN          NaN
# 3          NaN            NaN               NaN           NaN          NaN
# 4          NaN            NaN               NaN           NaN          NaN
#
# [5 rows x 109 columns]

# %%
#Show the last 5 lines
df.tail()
# Out:
#            Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 1999996  1999.0      1.0    1.0         5.0        2.0 1999-01-05
# 1999997  2003.0      4.0   11.0        14.0        5.0 2003-11-14
# 1999998  2012.0      2.0    5.0        15.0        2.0 2012-05-15
# 1999999  2003.0      2.0    4.0        29.0        2.0 2003-04-29
# 2000000     NaN      NaN    NaN         NaN        NaN        NaT
#
#         Reporting_Airline  DOT_ID_Reporting_Airline  \
# 1999996                CO                   19704.0
# 1999997                US                   20355.0
# 1999998                WN                   19393.0
# 1999999                UA                   19977.0
# 2000000               NaN                       NaN
#
#         IATA_CODE_Reporting_Airline Tail_Number  ...  Div4WheelsOff  \
# 1999996                          CO      N14308  ...            NaN
# 1999997                          US      N528AU  ...            NaN
# 1999998                          WN      N281WN  ...            NaN
# 1999999                          UA      N364UA  ...            NaN
# 2000000                         NaN         NaN  ...            NaN
#
#          Div4TailNum  Div5Airport  Div5AirportID Div5AirportSeqID  \
# 1999996          NaN          NaN            NaN              NaN
# 1999997          NaN          NaN            NaN              NaN
# 1999998          NaN          NaN            NaN              NaN
# 1999999          NaN          NaN            NaN              NaN
# 2000000          NaN          NaN            NaN              NaN
#
#         Div5WheelsOn Div5TotalGTime  Div5LongestGTime Div5WheelsOff  \
# 1999996          NaN            NaN               NaN           NaN
# 1999997          NaN            NaN               NaN           NaN
# 1999998          NaN            NaN               NaN           NaN
# 1999999          NaN            NaN               NaN           NaN
# 2000000          NaN            NaN               NaN           NaN
#
#          Div5TailNum
# 1999996          NaN
# 1999997          NaN
# 1999998          NaN
# 1999999          NaN
# 2000000          NaN
#
# [5 rows x 109 columns]

# %%
#Get a some information about the dataset
print("Shape:", df.shape, "\n"
      "Duplicated:", df.duplicated().sum(), "\n"
      "Null:", (df.isnull().sum(axis=1) == df.shape[1]).sum())
# Out:
# Shape: (2000001, 109)
# Duplicated: 0
# Null: 1

# %% [markdown]
# ## Cleaning the data

# %%
#Eliminate rows or columns where all the values are missing
df.dropna(axis = 0, how='all', inplace=True)
df.dropna(axis = 1, how='all', inplace=True)

#Eliminate Duplicates
df.drop_duplicates(inplace=True)

#Control the shape of the DataFrame
print("New Shape:", df.shape)
# Out:
# New Shape: (2000000, 85)

# %%
#Generate a list of columns to eliminate
col_todelete = ['Reporting_Airline',
            'IATA_CODE_Reporting_Airline',
            'Tail_Number',
            'Origin',
            'OriginCityName',
            'OriginState',
            'OriginStateName',
            'OriginWac',
            'Dest',
            'DestCityName',
            'DestState',
            'DestStateName',
            'DestWac',
            'CRSDepTime',
            'DepDelayMinutes',
            'DepartureDelayGroups',
            'DepTimeBlk',
            'CRSArrTime', 
            'ArrTime',
            'ArrDelay',
            'ArrDelayMinutes',
            'ArrDel15',
            'ArrivalDelayGroups',
            'ArrTimeBlk',
            'Cancelled',
            'CancellationCode',
            'CRSElapsedTime',
            'ActualElapsedTime',
            'CarrierDelay',
            'WeatherDelay', 
            'NASDelay',
            'SecurityDelay',
            'LateAircraftDelay',
            'Div1Airport',
            'Div2Airport',
            'DivActualElapsedTime',
            'DivArrDelay',
            'DivDistance',
            'Div1Airport',
            'Div1AirportID',
            'Div1AirportSeqID',
            'Div1WheelsOn',
            'Div1TotalGTime',
            'Div1LongestGTime',
            'Div1WheelsOff',
            'Div1TailNum',
            'Div2Airport',
            'Div2AirportID',
            'Div2AirportSeqID',
            'Div2WheelsOn',
            'Div2TotalGTime',
            'Div2LongestGTime',
            'Div2WheelsOff',
            'Div2TailNum'
]

print('Old Shape:', df.shape, '\n')

df.drop(columns=col_todelete, inplace=True)

print('New Shape:', df.shape)
# Out:
# Old Shape: (2000000, 85)
#
# New Shape: (2000000, 33)

# %%
#First lines of the dataset updated
df.head()
# Out:
#      Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 0  1998.0      1.0    1.0         2.0        5.0 1998-01-02
# 1  2009.0      2.0    5.0        28.0        4.0 2009-05-28
# 2  2013.0      2.0    6.0        29.0        6.0 2013-06-29
# 3  2010.0      3.0    8.0        31.0        2.0 2010-08-31
# 4  2006.0      1.0    1.0        15.0        7.0 2006-01-15
#
#    DOT_ID_Reporting_Airline  Flight_Number_Reporting_Airline  OriginAirportID  \
# 0                   19386.0                            675.0          13487.0
# 1                   20437.0                            671.0          13342.0
# 2                   20398.0                           3297.0          11921.0
# 3                   19790.0                           1806.0          12892.0
# 4                   20355.0                            465.0          11618.0
#
#    OriginAirportSeqID  ...  Diverted  AirTime  Flights  Distance  \
# 0           1348701.0  ...       0.0    153.0      1.0     991.0
# 1           1334202.0  ...       0.0    141.0      1.0    1066.0
# 2           1192102.0  ...       0.0    103.0      1.0     773.0
# 3           1289201.0  ...       0.0    220.0      1.0    1979.0
# 4           1161801.0  ...       0.0     80.0      1.0     529.0
#
#    DistanceGroup  FirstDepTime  TotalAddGTime  LongestAddGTime  \
# 0            4.0           NaN            NaN              NaN
# 1            5.0           NaN            NaN              NaN
# 2            4.0           NaN            NaN              NaN
# 3            8.0           NaN            NaN              NaN
# 4            3.0           NaN            NaN              NaN
#
#    DivAirportLandings  DivReachedDest
# 0                 NaN             NaN
# 1                 0.0             NaN
# 2                 0.0             NaN
# 3                 0.0             NaN
# 4                 NaN             NaN
#
# [5 rows x 33 columns]

# %%
df.to_pickle('airline_dataset_preprocessed')
